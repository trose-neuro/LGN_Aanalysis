# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

hour, direction = np.meshgrid(np.arange(24), np.arange(1,3))
df = pd.DataFrame({"hour": hour.flatten(), "direction": direction.flatten()})
df["hourly_avg_count"] = np.random.randint(14,30, size=len(df))

plt.figure(figsize=(12,8))
sns.lineplot(df, x='hour', y = "direction", 
               condition='direction', value='hourly_avg_count')

plt.show()

# %%
fmri = sns.load_dataset("fmri")

# %%
df.hour

# %%
dots = sns.load_dataset("dots")

# %%
sns.relplot(x="time", y="firing_rate", col="align",
            hue="choice", size="coherence", style="choice",
            facet_kws=dict(sharex=False),
            kind="line", legend="full", data=dots);

# %%
dots

# %%
l = dots.loc[1:20]

# %% [markdown]
# ### panda structure for PSTH
#
# Observations = timepoints
# subject = trials

# %%
k = fmri.loc[1:20]

# %%
k.signal

# %%
df1 = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum(), trial = [0] * 500, stim = ['ipsi'] * 500))
df2 = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum(), trial = [1] * 500, stim = ['contra'] * 500))
#f1 = pd.DataFrame(dict(time=np.arange(500),
 #                     value=np.random.randn(500).cumsum(), trial = [1] * 500, stim = ['ipsi'] * 500))
#f2 = pd.DataFrame(dict(time=np.arange(500),
#                      value=np.random.randn(500).cumsum(), trial = [1] * 500, stim = ['contra'] * 500))

df = df1.append(df2)

# %%
df.query("stim == 'ipsi' & trial == 1").to_numpy()

# %%
A=np.chararray((3,3),unicode=True)

# %%
type(p)

# %%
A[:] = 'cell'

# %%
schema = ['string'] * 20

# %%
schema

# %%
df1.query("trial == 0")

# %%
import pandas
import numpy
import seaborn as sns
import matplotlib.pyplot as plt

# Generate synthetic data
omega = numpy.linspace(0, 50)

A0s = [1., 18., 40., 100.]

dfs = []
for A0 in A0s:
    V_w_dr = numpy.sin(A0*omega)
    V_w_tr = numpy.cos(A0*omega)
    dfs.append(pandas.DataFrame({'omega': omega,
                                 'V_w_dr': V_w_dr,
                                 'V_w_tr': V_w_tr,
                                 'A0': A0}))
dataframe = pandas.concat(dfs, axis=0)

# %%
melted = dataframe.melt(id_vars=['A0', 'omega'], value_vars=['V_w_dr', 'V_w_tr'])
g = sns.FacetGrid(melted, col='A0', hue='A0', row='variable', sharey='row', margin_titles=True)
g.map(plt.plot, 'omega', 'value')

# %%
A0s
# Out:
# [1.0, 18.0, 40.0, 100.0]
